# %% [markdown]
# ## Exercise 6.1 - Sourcing Open Data
#
# ### Contents
#
# #### 1. Import Libraries and data
# #### 2. Data Cleaning and Wrangling
# #### 3. Export Dataset to .csv

# %% [markdown]
# ### 1. Import Libraries and Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Define Path
path = r'/Users/anfran/Desktop/Chocolate Rating Project'

# %%
#Import Dataset
rating = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'chocolate_data.csv'), index_col = False)

# %%
#Check head
rating.head()
# Out:
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# 4          2015            70%            France    3.50
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %%
#Check shape
rating.shape
# Out:
# (1795, 9)

# %%
#Check info
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company
# (Maker-if known)         1795 non-null   object
#  1   Specific Bean Origin
# or Bar Name  1795 non-null   object
#  2   REF                               1795 non-null   int64
#  3   Review
# Date                       1795 non-null   int64
#  4   Cocoa
# Percent                     1795 non-null   object
#  5   Company
# Location                  1795 non-null   object
#  6   Rating                            1795 non-null   float64
#  7   Bean
# Type                         1794 non-null   object
#  8   Broad Bean
# Origin                 1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
#Check basic statistics
rating.describe()
# Out:
#                REF  Review\nDate       Rating
# count  1795.000000   1795.000000  1795.000000
# mean   1035.904735   2012.325348     3.185933
# std     552.886365      2.927210     0.478062
# min       5.000000   2006.000000     1.000000
# 25%     576.000000   2010.000000     2.875000
# 50%    1069.000000   2013.000000     3.250000
# 75%    1502.000000   2015.000000     3.500000
# max    1952.000000   2017.000000     5.000000

# %% [markdown]
# ### 2. Data Cleaning and Wrangling

# %%
#Sort the Dataset by Review Date
rating.sort_values (by = ['Review\nDate'], inplace = True, ascending = True)

# %%
#Check results
rating.head()
# Out:
#               Company \n(Maker-if known) Specific Bean Origin\nor Bar Name  \
# 1177                 Neuhaus (Callebaut)                          Sao Tome
# 1292                    Pierre Marcolini   Porcelana, Tabasco, Limited Ed.
# 1237  Original Hawaiin Chocolate Factory        Hawai'i, Kona Estate Grown
# 1178                 Neuhaus (Callebaut)                           Ocumare
# 1176                 Neuhaus (Callebaut)                       West Africa
#
#       REF  Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 1177   15          2006            75%           Belgium    2.75  Forastero
# 1292   81          2006            72%           Belgium    4.00    Criollo
# 1237   24          2006            60%            U.S.A.    3.00
# 1178   24          2006            71%           Belgium    3.00    Criollo
# 1176   15          2006            73%           Belgium    2.00  Forastero
#
#      Broad Bean\nOrigin
# 1177           Sao Tome
# 1292             Mexico
# 1237             Hawaii
# 1178          Venezuela
# 1176        West Africa

# %%
#Change column names
rating.rename(columns={'Company \n(Maker-if known)': 'company_name', 'Specific Bean Origin\nor Bar Name': 'bean_origin', 
                       'Review\nDate': 'review_date', 'Cocoa\nPercent': 'cocoa_percent', 'Company\nLocation': 'company_location', 
                       'Bean\nType': 'bean_type', 'Broad Bean\nOrigin': 'broad_bean_origin'}, inplace=True)

# %%
#Check results
rating.head()
# Out:
#               Company \n(Maker-if known)                      bean_origin  \
# 1177                 Neuhaus (Callebaut)                         Sao Tome
# 1292                    Pierre Marcolini  Porcelana, Tabasco, Limited Ed.
# 1237  Original Hawaiin Chocolate Factory       Hawai'i, Kona Estate Grown
# 1178                 Neuhaus (Callebaut)                          Ocumare
# 1176                 Neuhaus (Callebaut)                      West Africa
#
#       REF  review_date cocoa_percent company_location  Rating  bean_type  \
# 1177   15         2006           75%          Belgium    2.75  Forastero
# 1292   81         2006           72%          Belgium    4.00    Criollo
# 1237   24         2006           60%           U.S.A.    3.00
# 1178   24         2006           71%          Belgium    3.00    Criollo
# 1176   15         2006           73%          Belgium    2.00  Forastero
#
#      broad_bean_origin
# 1177          Sao Tome
# 1292            Mexico
# 1237            Hawaii
# 1178         Venezuela
# 1176       West Africa

# %% [markdown]
# I'm not sure why the first column will not change it's name, but the rest of the columns changes. The name of the company column is not a huge deal.

# %%
#Check results
rating.head()
# Out:
#               Company \n(Maker-if known)                      bean_origin  \
# 1177                 Neuhaus (Callebaut)                         Sao Tome
# 1292                    Pierre Marcolini  Porcelana, Tabasco, Limited Ed.
# 1237  Original Hawaiin Chocolate Factory       Hawai'i, Kona Estate Grown
# 1178                 Neuhaus (Callebaut)                          Ocumare
# 1176                 Neuhaus (Callebaut)                      West Africa
#
#       REF  review_date cocoa_percent company_location  Rating  bean_type  \
# 1177   15         2006           75%          Belgium    2.75  Forastero
# 1292   81         2006           72%          Belgium    4.00    Criollo
# 1237   24         2006           60%           U.S.A.    3.00
# 1178   24         2006           71%          Belgium    3.00    Criollo
# 1176   15         2006           73%          Belgium    2.00  Forastero
#
#      broad_bean_origin
# 1177          Sao Tome
# 1292            Mexico
# 1237            Hawaii
# 1178         Venezuela
# 1176       West Africa

# %%
rating.shape
# Out:
# (1795, 9)

# %%
#Check for null values
rating.isnull().sum()
# Out:
# Company \n(Maker-if known)    0
# bean_origin                   0
# REF                           0
# review_date                   0
# cocoa_percent                 0
# company_location              0
# Rating                        0
# bean_type                     1
# broad_bean_origin             1
# dtype: int64

# %%
#Locate null values in 'bean_type'
df_nan1 = rating[rating['bean_type'].isnull()==True]

# %%
df_nan1
# Out:
#      Company \n(Maker-if known)                              bean_origin  REF  \
# 1544                       Soma  Three Amigos(Chuao, Wild Bolivia, D.R.)  676
#
#       review_date cocoa_percent company_location  Rating bean_type  \
# 1544         2011           70%           Canada     4.0       NaN
#
#        broad_bean_origin
# 1544  Ven, Bolivia, D.R.

# %%
#Replace NaN value with 'unknown'
rating['bean_type'].fillna('unknown', inplace=True)

# %%
#Check results
df_nan1 = rating[rating['bean_type'].isnull()==True]

# %%
df_nan1
# Out:
# Empty DataFrame
# Columns: [Company
# (Maker-if known), bean_origin, REF, review_date, cocoa_percent, company_location, Rating, bean_type, broad_bean_origin]
# Index: []

# %%
#Locate null values in 'broad_bean_origin'
df_nan2 = rating[rating['broad_bean_origin'].isnull()==True]

# %%
df_nan2
# Out:
#      Company \n(Maker-if known) bean_origin  REF  review_date cocoa_percent  \
# 1072              Mast Brothers  Madagascar  999         2012           72%
#
#      company_location  Rating   bean_type broad_bean_origin
# 1072           U.S.A.     2.5  Trinitario               NaN

# %%
#Replace NaN value with 'unknown'
rating['broad_bean_origin'].fillna('unknown', inplace=True)

# %%
#Check results
df_nan2 = rating[rating['broad_bean_origin'].isnull()==True]

# %%
df_nan2
# Out:
# Empty DataFrame
# Columns: [Company
# (Maker-if known), bean_origin, REF, review_date, cocoa_percent, company_location, Rating, bean_type, broad_bean_origin]
# Index: []

# %%
#Replace field that's entirely space (or empty) with NaN
rating.replace("", np.nan, inplace=True)

# %%
rating.head(25)
# Out:
#               Company \n(Maker-if known)                         bean_origin  \
# 1177                 Neuhaus (Callebaut)                            Sao Tome
# 1292                    Pierre Marcolini     Porcelana, Tabasco, Limited Ed.
# 1237  Original Hawaiin Chocolate Factory          Hawai'i, Kona Estate Grown
# 1178                 Neuhaus (Callebaut)                             Ocumare
# 1176                 Neuhaus (Callebaut)                         West Africa
# 1120                      Michel Cluizel                         Noir Infini
# 1439                    Scharffen Berger                          Extra Dark
# 1440                    Scharffen Berger                         Bittersweet
# 1441                    Scharffen Berger                    Kumasi Sambirano
# 1293                    Pierre Marcolini                  Kendem Lembu, Java
# 1119                      Michel Cluizel                         Maralumi P.
# 1117                      Michel Cluizel                      Los Ancones P.
# 1116                      Michel Cluizel                            Tamarina
# 1115                      Michel Cluizel                    Carre Grand Noir
# 1114                      Michel Cluizel                          Carre Amer
# 1442                    Scharffen Berger                Jamaica a l'ancienne
# 1443                    Scharffen Berger                           Semisweet
# 241                               Bonnat                             Trinite
# 242                               Bonnat             Ocumare, Puerto Cabello
# 1118                      Michel Cluizel                          Mangaro P.
# 1294                    Pierre Marcolini  Ocumare, Puerto Cabello, Venezuela
# 1323                              Pralus      Monte Alegre (Itacare), Brazil
# 86                                Amedei                       Toscano Black
# 1338                              Pralus            Djakarta, Java and Ghana
# 1337                              Pralus        Caracas, Venezuela and Ghana
#
#       REF  review_date cocoa_percent company_location  Rating  \
# 1177   15         2006           75%          Belgium    2.75
# 1292   81         2006           72%          Belgium    4.00
# 1237   24         2006           60%           U.S.A.    3.00
# 1178   24         2006           71%          Belgium    3.00
# 1176   15         2006           73%          Belgium    2.00
# 1120   81         2006           99%           France    2.00
# 1439   15         2006           82%           U.S.A.    2.00
# 1440   15         2006           70%           U.S.A.    3.50
# 1441   40         2006           68%           U.S.A.    2.00
# 1293   93         2006           72%          Belgium    3.00
# 1119   24         2006           64%           France    4.00
# 1117   24         2006           67%           France    4.00
# 1116   24         2006           70%           France    3.00
# 1115   24         2006           85%           France    2.00
# 1114   24         2006           60%           France    2.00
# 1442   56         2006           70%           U.S.A.    2.00
# 1443   56         2006           62%           U.S.A.    3.00
# 241    24         2006           75%           France    3.75
# 242    32         2006           75%           France    4.00
# 1118   24         2006           65%           France    4.00
# 1294   93         2006           72%          Belgium    4.00
# 1323  105         2006           75%           France    3.00
# 86     40         2006           70%            Italy    5.00
# 1338   99         2006           75%           France    3.50
# 1337   99         2006           75%           France    3.00
#
#                   bean_type   broad_bean_origin
# 1177              Forastero            Sao Tome
# 1292                Criollo              Mexico
# 1237                                     Hawaii
# 1178                Criollo           Venezuela
# 1176              Forastero         West Africa
# 1120
# 1439
# 1440                  Blend
# 1441                  Blend  Ghana & Madagascar
# 1293                Criollo           Indonesia
# 1119                           Papua New Guinea
# 1117                         Dominican Republic
# 1116              Forastero            Sao Tome
# 1115
# 1114
# 1442             Trinitario             Jamaica
# 1443                  Blend
# 241              Trinitario           Carribean
# 242                                   Venezuela
# 1118             Trinitario          Madagascar
# 1294                Criollo           Venezuela
# 1323              Forastero              Brazil
# 86                    Blend
# 1338     Criollo, Forastero    Indonesia, Ghana
# 1337  Trinitario, Forastero    Venezuela, Ghana

# %% [markdown]
# * The code(s) I have tried to replace the blank values (whitespace) values are not working, so I will handle this step in Excel.

# %%
#Check for duplicates
df_dups = rating[rating.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Company
# (Maker-if known), bean_origin, REF, review_date, cocoa_percent, company_location, Rating, bean_type, broad_bean_origin]
# Index: []

# %% [markdown]
# * No duplicates found.

# %%
#Check for mixed types
for col in rating.columns.tolist():
  weird = (rating[[col]].applymap(type) != rating[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (rating[weird]) > 0:
    print (col, ' mixed')

# %% [markdown]
# * No mixed data types were found

# %%
#Check clean dataframe
rating.head()
# Out:
#               Company \n(Maker-if known)                      bean_origin  \
# 1177                 Neuhaus (Callebaut)                         Sao Tome
# 1292                    Pierre Marcolini  Porcelana, Tabasco, Limited Ed.
# 1237  Original Hawaiin Chocolate Factory       Hawai'i, Kona Estate Grown
# 1178                 Neuhaus (Callebaut)                          Ocumare
# 1176                 Neuhaus (Callebaut)                      West Africa
#
#       REF  review_date cocoa_percent company_location  Rating  bean_type  \
# 1177   15         2006           75%          Belgium    2.75  Forastero
# 1292   81         2006           72%          Belgium    4.00    Criollo
# 1237   24         2006           60%           U.S.A.    3.00
# 1178   24         2006           71%          Belgium    3.00    Criollo
# 1176   15         2006           73%          Belgium    2.00  Forastero
#
#      broad_bean_origin
# 1177          Sao Tome
# 1292            Mexico
# 1237            Hawaii
# 1178         Venezuela
# 1176       West Africa

# %%
rating.shape
# Out:
# (1795, 9)

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1795 entries, 1177 to 958
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company
# (Maker-if known)  1795 non-null   object
#  1   bean_origin                1795 non-null   object
#  2   REF                        1795 non-null   int64
#  3   review_date                1795 non-null   int64
#  4   cocoa_percent              1795 non-null   object
#  5   company_location           1795 non-null   object
#  6   Rating                     1795 non-null   float64
#  7   bean_type                  1795 non-null   object
#  8   broad_bean_origin          1795 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 140.2+ KB

# %%
rating.describe()
# Out:
#                REF  review_date       Rating
# count  1795.000000  1795.000000  1795.000000
# mean   1035.904735  2012.325348     3.185933
# std     552.886365     2.927210     0.478062
# min       5.000000  2006.000000     1.000000
# 25%     576.000000  2010.000000     2.875000
# 50%    1069.000000  2013.000000     3.250000
# 75%    1502.000000  2015.000000     3.500000
# max    1952.000000  2017.000000     5.000000

# %% [markdown]
# ### 3. Export Data

# %%
rating.to_csv(os.path.join(path, '02 Data','Prepared Data', 'chocolate_rating_clean.csv'))
